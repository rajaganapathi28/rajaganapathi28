# %% [markdown]
# <a href="https://colab.research.google.com/github/rajaganapathi28/rajaganapathi28/blob/main/ProjectFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>What is Colab?</h2>
# </div>
#
# Colab, or "Colaboratory", allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) or [Colab Features You May Have Missed](https://www.youtube.com/watch?v=rNgswRZ2C1Y) to learn more, or just get started below!

# %%
import pandas as pd
smartphones = pd.read_csv("/content/Smartphones_cleaned_dataset.csv")
smartphones
# Out:
#     brand_name                            model  price  rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999    89.0    True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989    81.0    True
# 2      samsung            Samsung Galaxy A14 5G  16499    75.0    True
# 3     motorola             Motorola Moto G62 5G  14999    81.0    True
# 4       realme               Realme 10 Pro Plus  24999    82.0    True
# ..         ...                              ...    ...     ...     ...
# 975   motorola       Motorola Moto Edge S30 Pro  34990    83.0    True
# 976      honor                      Honor X8 5G  14990    75.0    True
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0    True
# 978   motorola             Motorola Moto G91 5G  19990    80.0    True
# 979    samsung           Samsung Galaxy M52s 5G  24990    74.0    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# ...

# %%
smartphones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int64
#  3   rating                     879 non-null    float64
#  4   has_5g                     980 non-null    bool
#  5   has_nfc                    980 non-null    bool
#  6   has_ir_blaster             980 non-null    bool
#  7   processor_brand            960 non-null    object
#  8   num_cores                  974 non-null    float64
#  9   processor_speed            938 non-null    float64
#  10  battery_capacity           969 non-null    float64
#  11  fast_charging_available    980 non-null    int64
#  12  fast_charging              769 non-null    float64
# ...

# %%
smartphones.describe()
# Out:
#                price      rating   num_cores  processor_speed  \
# count     980.000000  879.000000  974.000000       938.000000
# mean    32520.504082   78.258248    7.772074         2.427217
# std     39531.812669    7.402854    0.836845         0.464090
# min      3499.000000   60.000000    4.000000         1.200000
# 25%     12999.000000   74.000000    8.000000         2.050000
# 50%     19994.500000   80.000000    8.000000         2.300000
# 75%     35491.500000   84.000000    8.000000         2.840000
# max    650000.000000   89.000000    8.000000         3.220000
#
#        battery_capacity  fast_charging_available  fast_charging  ram_capacity  \
# count        969.000000               980.000000     769.000000    980.000000
# mean        4817.748194                 0.854082      46.126138      6.560204
# std         1009.540054                 0.353205      34.277870      2.744378
# min         1821.000000                 0.000000      10.000000      1.000000
# ...

# %%
smartphones.shape
# Out:
# (980, 26)

# %%
smartphones.columns
# Out:
# Index(['brand_name', 'model', 'price', 'rating', 'has_5g', 'has_nfc',
#        'has_ir_blaster', 'processor_brand', 'num_cores', 'processor_speed',
#        'battery_capacity', 'fast_charging_available', 'fast_charging',
#        'ram_capacity', 'internal_memory', 'screen_size', 'refresh_rate',
#        'num_rear_cameras', 'num_front_cameras', 'os', 'primary_camera_rear',
#        'primary_camera_front', 'extended_memory_available', 'extended_upto',
#        'resolution_width', 'resolution_height'],
#       dtype='object')

# %%
smartphones.dtypes
# Out:
# brand_name                    object
# model                         object
# price                          int64
# rating                       float64
# has_5g                          bool
# has_nfc                         bool
# has_ir_blaster                  bool
# processor_brand               object
# num_cores                    float64
# processor_speed              float64
# battery_capacity             float64
# fast_charging_available        int64
# fast_charging                float64
# ram_capacity                   int64
# internal_memory                int64
# screen_size                  float64
# refresh_rate                   int64
# num_rear_cameras               int64
# num_front_cameras            float64
# os                            object
# primary_camera_rear          float64
# primary_camera_front         float64
# extended_memory_available      int64
# extended_upto                float64
# resolution_width               int64
# ...

# %%
smartphones.nunique()
# Out:
# brand_name                    46
# model                        980
# price                        379
# rating                        30
# has_5g                         2
# has_nfc                        2
# has_ir_blaster                 2
# processor_brand               13
# num_cores                      3
# processor_speed               35
# battery_capacity              89
# fast_charging_available        2
# fast_charging                 32
# ram_capacity                   9
# internal_memory                8
# screen_size                   79
# refresh_rate                   6
# num_rear_cameras               4
# num_front_cameras              2
# os                             3
# primary_camera_rear           18
# primary_camera_front          24
# extended_memory_available      2
# extended_upto                  7
# resolution_width              40
# resolution_height             65
# dtype: int64

# %%
smartphones.isna().sum()
# Out:
# brand_name                     0
# model                          0
# price                          0
# rating                       101
# has_5g                         0
# has_nfc                        0
# has_ir_blaster                 0
# processor_brand               20
# num_cores                      6
# processor_speed               42
# battery_capacity              11
# fast_charging_available        0
# fast_charging                211
# ram_capacity                   0
# internal_memory                0
# screen_size                    0
# refresh_rate                   0
# num_rear_cameras               0
# num_front_cameras              4
# os                            14
# primary_camera_rear            0
# primary_camera_front           5
# extended_memory_available      0
# extended_upto                480
# resolution_width               0
# resolution_height              0
# dtype: int64

# %%
smartphones.loc[1:50]
# Out:
#    brand_name                                        model   price  rating  \
# 1     oneplus                    OnePlus Nord CE 2 Lite 5G   19989    81.0
# 2     samsung                        Samsung Galaxy A14 5G   16499    75.0
# 3    motorola                         Motorola Moto G62 5G   14999    81.0
# 4      realme                           Realme 10 Pro Plus   24999    82.0
# 5     samsung      Samsung Galaxy F23 5G (6GB RAM + 128GB)   16999    80.0
# 6       apple                              Apple iPhone 14   65999    81.0
# 7      xiaomi                Xiaomi Redmi Note 12 Pro Plus   29999    86.0
# 8     nothing                              Nothing Phone 1   26749    85.0
# 9     oneplus                           OnePlus Nord 2T 5G   28999    84.0
# 10     realme                                Realme 10 Pro   18999    82.0
# 11       oppo                                     Oppo A78   18999    79.0
# ...

# %%
smartphones["brand_name"].nunique()
# Out:
# 46

# %%
smartphones["model"].unique()
# Out:
# array(['OnePlus 11 5G', 'OnePlus Nord CE 2 Lite 5G',
#        'Samsung Galaxy A14 5G', 'Motorola Moto G62 5G',
#        'Realme 10 Pro Plus', 'Samsung Galaxy F23 5G (6GB RAM + 128GB)',
#        'Apple iPhone 14', 'Xiaomi Redmi Note 12 Pro Plus',
#        'Nothing Phone 1', 'OnePlus Nord 2T 5G', 'Realme 10 Pro',
#        'Oppo A78', 'Xiaomi Redmi Note 12 Pro 5G',
#        'Vivo T1 5G (6GB RAM + 128GB)', 'Samsung Galaxy S23 Ultra 5G',
#        'Apple iPhone 13', 'Vivo Y16', 'OPPO Reno 9 Pro Plus',
#        'OnePlus 10R 5G', 'Vivo Y22', 'OnePlus 11R', 'Vivo V25 Pro 5G',
#        'Poco X4 Pro 5G', 'Xiaomi Redmi Note 12', 'Vivo V26 Pro',
#        'Samsung Galaxy S20 FE 5G',
#        'OnePlus Nord CE 2 Lite 5G (8GB RAM + 128GB)',
#        'Apple iPhone 14 Pro Max', 'Vivo V25 5G', 'OnePlus 11 Pro',
#        'Realme 10 Pro (8GB RAM + 128GB)', 'Poco X5 Pro', 'Vivo V27',
#        'Apple iPhone 11', 'Samsung Galaxy M53 5G',
#        'Samsung Galaxy S21 FE 5G', 'Oppo Reno 8T',
# ...

# %%
smartphones_SD = smartphones[smartphones["processor_brand"]=='snapdragon']
smartphones_SD
# Out:
#     brand_name                                    model   price  rating  \
# 0      oneplus                            OnePlus 11 5G   54999    89.0
# 1      oneplus                OnePlus Nord CE 2 Lite 5G   19989    81.0
# 3     motorola                     Motorola Moto G62 5G   14999    81.0
# 5      samsung  Samsung Galaxy F23 5G (6GB RAM + 128GB)   16999    80.0
# 8      nothing                          Nothing Phone 1   26749    85.0
# ..         ...                                      ...     ...     ...
# 971       oppo                             Oppo Find X6   69990    89.0
# 974       vivo                            Vivo X Fold 2  119990     NaN
# 975   motorola               Motorola Moto Edge S30 Pro   34990    83.0
# 976      honor                              Honor X8 5G   14990    75.0
# 978   motorola                     Motorola Moto G91 5G   19990    80.0
#
#      has_5g  has_nfc  has_ir_blaster processor_brand  num_cores  \
# ...

# %%
smartphones_SD = smartphones[smartphones["processor_brand"]=='bionic']
smartphones_SD
# Out:
#     brand_name                            model   price  rating  has_5g  \
# 6        apple                  Apple iPhone 14   65999    81.0    True
# 15       apple                  Apple iPhone 13   62999    79.0    True
# 27       apple          Apple iPhone 14 Pro Max  129990    76.0    True
# 33       apple                  Apple iPhone 11   38999    73.0   False
# 56       apple             Apple iPhone 14 Plus   74999    82.0    True
# 76       apple              Apple iPhone 13 Pro  119900    83.0    True
# 100      apple              Apple iPhone 14 Pro  119990    75.0    True
# 111      apple                  Apple iPhone 12   51999    74.0    True
# 136      apple          Apple iPhone 11 (128GB)   46999    75.0   False
# 149      apple             Apple iPhone 12 Mini   40999    74.0    True
# 152      apple          Apple iPhone 15 Pro Max  142990    79.0    True
# 161      apple          Apple iPhone 13 Pro Max  129900    84.0    True
# ...

# %%
smartphones['rating'].value_counts()
# Out:
# rating
# 84.0    60
# 82.0    58
# 83.0    55
# 75.0    53
# 85.0    50
# 80.0    49
# 86.0    47
# 79.0    45
# 77.0    38
# 78.0    36
# 89.0    35
# 81.0    35
# 87.0    33
# 74.0    30
# 76.0    29
# 88.0    26
# 71.0    21
# 72.0    18
# 69.0    18
# 73.0    16
# 61.0    15
# 66.0    15
# 65.0    14
# 70.0    14
# 68.0    13
# 67.0    13
# 60.0    12
# 62.0    11
# 64.0    10
# 63.0    10
# Name: count, dtype: int64

# %%
smartphones['has_nfc'].value_counts()
# Out:
# has_nfc
# False    587
# True     393
# Name: count, dtype: int64

# %%
smartphones['has_nfc'].sort_index()
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 975    False
# 976    False
# 977     True
# 978     True
# 979    False
# Name: has_nfc, Length: 980, dtype: bool

# %%
smartphones['has_5g'].sort_values()
# Out:
# 604    False
# 313    False
# 755    False
# 505    False
# 757    False
#        ...
# 363     True
# 364     True
# 366     True
# 347     True
# 979     True
# Name: has_5g, Length: 980, dtype: bool

# %%
smartphones['price'].unique()
# Out:
# array([ 54999,  19989,  16499,  14999,  24999,  16999,  65999,  29999,
#         26749,  28999,  18999,  24762,  16990, 114990,  62999,   9999,
#         45999,  32999,  14499,  39999,  35999,  17859,  42990,  31239,
#         21995, 129990,  27999,  69999,  19999,  20999,  27990,  38999,
#         23790,  29990,  91999,  28499,  21999,  18499,  17478,  11936,
#          8950,  12489,  42999,  11990,  13999,  14965,  74999,  10999,
#         84990,  10499,  17990,  35499,  60999,  15999,  99990,   9499,
#         27994,  13989,  44999,   6190, 119900,  27660,   8388,  19990,
#         22999,  14290,  41999,  13489,  22990,  73999,  12499,  59999,
#        106990,  15990, 119990,  23990,  12999,  58990,  43999,  49999,
#         36999,  51999,  31999,   6171,  29340,  25289,  21788,  70990,
#         34999,  33900,  19499,  24994,  25999,  34990,  13466,   7999,
#         28249,  46999,  13490,  15499,   4499,   8499,  24990,   9589,
# ...

# %%
smartphones['price'].value_counts()
# Out:
# price
# 14999    21
# 11999    17
# 19990    17
# 16999    16
# 19999    16
#          ..
# 14590     1
# 64800     1
# 11700     1
# 22998     1
# 18000     1
# Name: count, Length: 379, dtype: int64

# %%
smartphones[smartphones["processor_brand"]=="mediatek"]
# Out:
#     brand_name                    model  price  rating  has_5g  has_nfc  \
# 827    samsung  Samsung Galaxy A01 Core   4999     NaN   False    False
#
#      has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# 827           False        mediatek        4.0              1.5  ...
#
#      refresh_rate  num_rear_cameras  num_front_cameras       os  \
# 827            60                 1                1.0  android
#
#      primary_camera_rear  primary_camera_front  extended_memory_available  \
# 827                  8.0                   5.0                          1
#
#      extended_upto  resolution_width resolution_height
# 827            NaN               720              1480
#
# [1 rows x 26 columns]

# %%
smartphones[smartphones["processor_brand"]=="snapdragon"]
# Out:
#     brand_name                                    model   price  rating  \
# 0      oneplus                            OnePlus 11 5G   54999    89.0
# 1      oneplus                OnePlus Nord CE 2 Lite 5G   19989    81.0
# 3     motorola                     Motorola Moto G62 5G   14999    81.0
# 5      samsung  Samsung Galaxy F23 5G (6GB RAM + 128GB)   16999    80.0
# 8      nothing                          Nothing Phone 1   26749    85.0
# ..         ...                                      ...     ...     ...
# 971       oppo                             Oppo Find X6   69990    89.0
# 974       vivo                            Vivo X Fold 2  119990     NaN
# 975   motorola               Motorola Moto Edge S30 Pro   34990    83.0
# 976      honor                              Honor X8 5G   14990    75.0
# 978   motorola                     Motorola Moto G91 5G   19990    80.0
#
#      has_5g  has_nfc  has_ir_blaster processor_brand  num_cores  \
# ...

# %%
smartphones[smartphones["processor_brand"]=="bionic"]
# Out:
#     brand_name                            model   price  rating  has_5g  \
# 6        apple                  Apple iPhone 14   65999    81.0    True
# 15       apple                  Apple iPhone 13   62999    79.0    True
# 27       apple          Apple iPhone 14 Pro Max  129990    76.0    True
# 33       apple                  Apple iPhone 11   38999    73.0   False
# 56       apple             Apple iPhone 14 Plus   74999    82.0    True
# 76       apple              Apple iPhone 13 Pro  119900    83.0    True
# 100      apple              Apple iPhone 14 Pro  119990    75.0    True
# 111      apple                  Apple iPhone 12   51999    74.0    True
# 136      apple          Apple iPhone 11 (128GB)   46999    75.0   False
# 149      apple             Apple iPhone 12 Mini   40999    74.0    True
# 152      apple          Apple iPhone 15 Pro Max  142990    79.0    True
# 161      apple          Apple iPhone 13 Pro Max  129900    84.0    True
# ...

# %%
smartphones["processor_brand"].value_counts().head(500).plot(kind="bar")
# Out:
# <Axes: xlabel='processor_brand'>

# %%
smartphones["brand_name"].value_counts().head(300).plot(kind="line")
# Out:
# <Axes: xlabel='brand_name'>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from scipy import stats

# %%
smartphones =pd.read_csv("/content/Smartphones_cleaned_dataset.csv")
smartphones
# Out:
#     brand_name                            model  price  rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999    89.0    True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989    81.0    True
# 2      samsung            Samsung Galaxy A14 5G  16499    75.0    True
# 3     motorola             Motorola Moto G62 5G  14999    81.0    True
# 4       realme               Realme 10 Pro Plus  24999    82.0    True
# ..         ...                              ...    ...     ...     ...
# 975   motorola       Motorola Moto Edge S30 Pro  34990    83.0    True
# 976      honor                      Honor X8 5G  14990    75.0    True
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0    True
# 978   motorola             Motorola Moto G91 5G  19990    80.0    True
# 979    samsung           Samsung Galaxy M52s 5G  24990    74.0    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# ...

# %%
smartphones.columns
# Out:
# Index(['brand_name', 'model', 'price', 'rating', 'has_5g', 'has_nfc',
#        'has_ir_blaster', 'processor_brand', 'num_cores', 'processor_speed',
#        'battery_capacity', 'fast_charging_available', 'fast_charging',
#        'ram_capacity', 'internal_memory', 'screen_size', 'refresh_rate',
#        'num_rear_cameras', 'num_front_cameras', 'os', 'primary_camera_rear',
#        'primary_camera_front', 'extended_memory_available', 'extended_upto',
#        'resolution_width', 'resolution_height'],
#       dtype='object')

# %%
smartphones.dtypes
# Out:
# brand_name                    object
# model                         object
# price                          int64
# rating                       float64
# has_5g                          bool
# has_nfc                         bool
# has_ir_blaster                  bool
# processor_brand               object
# num_cores                    float64
# processor_speed              float64
# battery_capacity             float64
# fast_charging_available        int64
# fast_charging                float64
# ram_capacity                   int64
# internal_memory                int64
# screen_size                  float64
# refresh_rate                   int64
# num_rear_cameras               int64
# num_front_cameras            float64
# os                            object
# primary_camera_rear          float64
# primary_camera_front         float64
# extended_memory_available      int64
# extended_upto                float64
# resolution_width               int64
# ...

# %%
smartphones['price'].unique()
# Out:
# array([ 54999,  19989,  16499,  14999,  24999,  16999,  65999,  29999,
#         26749,  28999,  18999,  24762,  16990, 114990,  62999,   9999,
#         45999,  32999,  14499,  39999,  35999,  17859,  42990,  31239,
#         21995, 129990,  27999,  69999,  19999,  20999,  27990,  38999,
#         23790,  29990,  91999,  28499,  21999,  18499,  17478,  11936,
#          8950,  12489,  42999,  11990,  13999,  14965,  74999,  10999,
#         84990,  10499,  17990,  35499,  60999,  15999,  99990,   9499,
#         27994,  13989,  44999,   6190, 119900,  27660,   8388,  19990,
#         22999,  14290,  41999,  13489,  22990,  73999,  12499,  59999,
#        106990,  15990, 119990,  23990,  12999,  58990,  43999,  49999,
#         36999,  51999,  31999,   6171,  29340,  25289,  21788,  70990,
#         34999,  33900,  19499,  24994,  25999,  34990,  13466,   7999,
#         28249,  46999,  13490,  15499,   4499,   8499,  24990,   9589,
# ...

# %%
smartphones['internal_memory'].unique()
# Out:
# array([ 256,  128,   64,   32,  512, 1024,   16,    8])

# %%
smartphones['processor_speed'].unique()
# Out:
# array([3.2 , 2.2 , 2.4 , 2.6 , 3.22, 2.5 , 3.  , 2.3 , 2.85, 2.  , 2.84,
#         nan, 2.65, 2.9 , 2.36, 1.8 , 3.1 , 2.05, 3.05, 1.4 , 1.82, 1.6 ,
#        2.8 , 1.3 , 2.73, 2.7 , 1.5 , 2.96, 2.35, 2.37, 3.13, 1.99, 2.86,
#        1.95, 2.1 , 1.2 ])

# %%
smartphones['screen_size'].unique()
# Out:
# array([6.7 , 6.59, 6.6 , 6.55, 6.1 , 6.67, 6.43, 6.72, 6.56, 6.58, 6.8 ,
#        6.51, 6.5 , 6.44, 6.4 , 6.78, 7.1 , 6.26, 6.53, 8.03, 6.73, 6.52,
#        6.14, 6.47, 6.62, 5.  , 5.4 , 6.68, 6.54, 4.7 , 3.54, 6.9 , 6.82,
#        6.95, 8.02, 6.3 , 6.71, 5.42, 6.36, 6.  , 6.81, 7.6 , 7.8 , 5.45,
#        6.2 , 6.83, 5.7 , 6.49, 6.06, 5.9 , 7.92, 6.18, 4.5 , 5.5 , 6.74,
#        6.35, 6.66, 6.64, 6.28, 6.92, 6.76, 6.57, 6.91, 7.4 , 6.38, 7.  ,
#        8.01, 6.39, 6.22, 4.  , 5.3 , 5.84, 7.2 , 6.34, 6.09, 8.  , 5.2 ,
#        6.75, 5.86])

# %%
smartphones['battery_capacity'].unique()
# Out:
# array([ 5000.,  3279.,  4980.,  4500.,  3240.,  4700.,  4830.,  4800.,
#         4323.,  3110.,  5200.,  6000.,  4325.,  4600.,  4200.,  3500.,
#         3095.,  4020.,  3200.,  4400.,  4310.,  4820.,  3700.,  5160.,
#           nan,  5080.,  3900.,  4410.,  5020.,  2800.,  4352.,  4520.,
#         4810.,  4000.,  2050.,  2150.,  4610.,  5100.,  7000.,  4300.,
#         5500.,  4050.,  4355.,  3060.,  5003.,  2438.,  4250.,  3300.,
#         4450.,  4614.,  4870.,  4030.,  4350.,  4100., 21000.,  4860.,
#         2275.,  4230.,  1900.,  3020.,  4730.,  3520.,  4080.,  5050.,
#         5600.,  4470.,  3360.,  3000.,  2230.,  9800.,  1821.,  4015.,
#         3285.,  4360.,  3315.,  2000.,  3600.,  3100., 22000.,  2400.,
#         2500.,  4532.,  5065.,  4620.,  4780.,  3730.,  3400.,  2730.,
#         5180.,  8000.])

# %%
smartphones['num_front_cameras'].unique()
# Out:
# array([ 1., nan,  2.])

# %%
smartphones['num_rear_cameras'].unique()
# Out:
# array([3, 2, 4, 1])

# %%
smartphones['primary_camera_rear'].unique()
# Out:
# array([ 50. ,  64. , 108. ,  12. , 200. ,  13. ,  48. ,   8. ,  50.3,
#         12.2,   5. ,  54. ,  16. ,   2. ,  20. ,  47.2,  40. ,  24. ])

# %%
smartphones['os'].unique()
# Out:
# array(['android', 'ios', 'other', nan], dtype=object)

# %%
smartphones['refresh_rate'].unique()
# Out:
# array([120,  90,  60, 144, 165, 240])

# %%
sns.heatmap(smartphones.isnull())
# Out:
# <Axes: >

# %%
stk_mean= smartphones['internal_memory'].mean()
stk_mean
# Out:
# np.float64(141.03673469387755)

# %%
smartphones['processor_speed'].value_counts()
# Out:
# processor_speed
# 2.00    146
# 2.20    135
# 2.40    128
# 3.20     94
# 2.30     86
# 3.00     53
# 2.84     36
# 2.05     28
# 2.50     23
# 1.80     23
# 1.60     20
# 2.85     19
# 3.22     18
# 3.10     15
# 2.60     14
# 2.90     13
# 1.82     10
# 1.30     10
# 2.80      9
# 2.73      9
# 3.05      8
# 2.36      8
# 2.65      5
# 1.40      5
# 2.70      5
# 1.50      4
# 2.96      3
# 2.86      3
# 3.13      2
# 2.37      1
# 2.35      1
# 1.99      1
# 1.95      1
# 2.10      1
# 1.20      1
# Name: count, dtype: int64

# %%
smartphones.fillna({'processor_speed':'low'},inplace=True)

# %%
sns.heatmap(smartphones.isnull())
# Out:
# <Axes: >

# %%
smartphones.isna().sum()
# Out:
# brand_name                     0
# model                          0
# price                          0
# rating                       101
# has_5g                         0
# has_nfc                        0
# has_ir_blaster                 0
# processor_brand               20
# num_cores                      6
# processor_speed                0
# battery_capacity              11
# fast_charging_available        0
# fast_charging                211
# ram_capacity                   0
# internal_memory                0
# screen_size                    0
# refresh_rate                   0
# num_rear_cameras               0
# num_front_cameras              4
# os                            14
# primary_camera_rear            0
# primary_camera_front           5
# extended_memory_available      0
# extended_upto                480
# resolution_width               0
# resolution_height              0
# dtype: int64

# %%
smartphones_SD= smartphones[['rating','has_5g','price']]
smartphones_SD
# Out:
#      rating  has_5g  price
# 0      89.0    True  54999
# 1      81.0    True  19989
# 2      75.0    True  16499
# 3      81.0    True  14999
# 4      82.0    True  24999
# ..      ...     ...    ...
# 975    83.0    True  34990
# 976    75.0    True  14990
# 977    85.0    True  28990
# 978    80.0    True  19990
# 979    74.0    True  24990
#
# [980 rows x 3 columns]

# %%
mobilesdetails.plot(kind='bar')
# Out:
# <Axes: xlabel='rating'>

# %%
mobilesdetails = smartphones_SD.groupby('rating').mean().sort_values(ascending=True,by ='price')
mobilesdetails
# Out:
#           has_5g         price
# rating
# 61.0    0.000000   8843.866667
# 66.0    0.000000   9161.800000
# 64.0    0.100000   9263.500000
# 65.0    0.000000   9719.285714
# 68.0    0.076923  10210.923077
# 67.0    0.153846  10892.461538
# 71.0    0.142857  12813.285714
# 69.0    0.222222  13882.166667
# 63.0    0.000000  14242.800000
# 74.0    0.200000  15767.200000
# 73.0    0.250000  15958.187500
# 60.0    0.083333  16563.583333
# 70.0    0.071429  16739.500000
# 72.0    0.166667  17560.944444
# 75.0    0.452830  23597.264151
# 80.0    0.591837  25743.142857
# 82.0    0.689655  26342.862069
# 77.0    0.315789  27270.868421
# 76.0    0.586207  27410.172414
# 79.0    0.666667  27722.911111
# 78.0    0.583333  27780.694444
# 81.0    0.657143  28641.485714
# 83.0    0.800000  32292.200000
# 84.0    0.783333  33119.816667
# 85.0    0.960000  34916.580000
# 86.0    0.914894  45345.468085
# 87.0    0.939394  46238.181818
# 89.0    0.942857  62975.085714
# 62.0    0.000000  68243.000000
# ...

# %%
import numpy as numpy
smartphones_SD.pivot_table(index="rating", values="price", aggfunc=np.sum).sort_values(ascending=False, by="price").head(10)
# Out:
# /tmp/ipython-input-14-3390056329.py:2: FutureWarning: The provided callable <function sum at 0x7aa65df9d260> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   smartphones_SD.pivot_table(index="rating", values="price", aggfunc=np.sum).sort_values(ascending=False, by="price").head(10)
#           price
# rating
# 89.0    2204128
# 86.0    2131237
# 84.0    1987189
# 88.0    1963487
# 83.0    1776071
# 85.0    1745829
# 82.0    1527886
# 87.0    1525860
# 80.0    1261414
# 75.0    1250655

# %%
cor_mat = smartphones.corr(numeric_only=True)
plt.figure(figsize=(15,20))
sns.heatmap(cor_mat,annot=True)
plt.show()

# %%
sns.lineplot(data=smartphones, x='price', y='rating', color='purple')
# Out:
# <Axes: xlabel='price', ylabel='rating'>

# %% [markdown]
# Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including [GPUs and TPUs](#using-accelerated-hardware), regardless of the power of your machine. All you need is a browser.
#
# For example, if you find yourself waiting for **pandas** code to finish running and want to go faster, you can switch to a GPU Runtime and use libraries like [RAPIDS cuDF](https://rapids.ai/cudf-pandas) that provide zero-code-change acceleration.

# %% [markdown]
# To learn more about accelerating pandas on Colab, see the [10 minute guide](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_colab_demo.ipynb) or
#  [US stock market data analysis demo](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_stocks_demo.ipynb).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Machine learning
# </div>
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just [a few lines of code](https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb).

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the [machine learning examples](#machine-learning-examples) below.
